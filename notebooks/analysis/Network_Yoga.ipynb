# %%
# access google drive folder
# %cd /content/drive/MyDrive/Yoga_Classes

# running the files containing neccesary libraries and functions
# %run 'notebooks/scripts/setup.ipynb'
# %run 'notebooks/scripts/networks.ipynb'
# Out:
# /content/drive/MyDrive/Yoga_Classes

# %% [markdown]
# ## Load data

# %%
# read data from csv
df_topic_keywords = pd.read_csv('data/df_topic_keywords.csv', index_col=0)
df_topics = pd.read_csv('data/df_with_topics.csv', index_col=0)

# set nodes name variables
styles = df_topics['class_style'].unique()
topics = df_topics['dominant_topic_theme'].unique()

# %% [markdown]
# # Network 1. *Narrative topic - Narrative topic* Relation

# %% [markdown]
# ### Construct the Graph

# %%
graph_1 = build_network_1(df_topic_keywords)

# %% [markdown]
# ### Visualize the network

# %% [markdown]
# Visualisation parameters:
#
# - node size is proportional to degree centrality of the node
# - edge width and color are proportional to edge weights

# %%
# save the graph data to import to Gephi for visualisation
graph_to_csv(graph_1, '', 'graph_1')

# %% [markdown]
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=1e_NCHPxzBwCeD9spJuPvhVOHFPKZN0xK'/>
# <figcaption>Network 1: Narrative topic - Narrative topic</figcaption></center>
# </figure>

# %% [markdown]
# ### Calculate general Graph statistics

# %%
general_graph_stats_1 = general_graph_statistics(graph_1)
general_graph_stats_1
# Out:
#        clustering_coefficient  average_shortest_path  network_density  \
# score                0.638881                0.24776              1.0
#
#        network_transitivity
# score                   1.0

# %% [markdown]
# ### Calculate centrality measures

# %%
centralities_1 = calculate_centralities(graph_1)
centralities_1
# Out:
#                               node  degree_centrality  betweenness_centrality  \
# 0            Balance and Alignment             1.0601                     0.0
# 1  Stress Relief/Breath Techniques             0.9373                     0.0
# 2    Deep Relaxation/Mind Practice             1.0025                     0.0
# 3              Stretch and Release             1.1729                     0.0
# 4                Core and Strength             0.7824                     0.0
#
#    eigenvector_centrality  closeness_centrality
# 0                0.470362              3.773229
# 1                0.425768              4.267577
# 2                0.453099              3.990025
# 3                0.510626              3.410350
# 4                0.362550              5.112474

# %%
plot_centralities_distributions(centralities_1)

# %% [markdown]
# ### Investigate Groups of nodes

# %%
clusters_1 = calculate_clusters(graph_1)
clusters_1
# Out:
#    Cluster                                            Members
# 0        1  ({Balance and Alignment}, {Core and Strength, ...
# 1        2  ({Balance and Alignment}, {Stress Relief/Breat...
# 2        3  ({Balance and Alignment}, {Stress Relief/Breat...
# 3        4  ({Balance and Alignment}, {Stress Relief/Breat...

# %%
communities_1 = detect_communities(graph_1)
communities_1
# Out:
#    Community                                            Members
# 0          1  (Stress Relief/Breath Techniques, Deep Relaxat...

# %% [markdown]
# # Network 2. *Class style - Class style* Relation

# %% [markdown]
# ### Construct the Graph

# %%
graph_2 = build_network_2(df_topics)

# %% [markdown]
# ### Visualize the network

# %% [markdown]
# Visualisation parameters:
#
# - node size is proportional to degree centrality of the node
# - edge width and color are proportional to edge weights

# %%
# save the graph data to import to Gephi for visualisation

graph_to_csv(graph_2, '', 'graph_2')

# %% [markdown]
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=1eN5s-T209eOyF5pFgRyrfDwHfnfX7Np4'/>
# <figcaption>Network 2: Class Style - Class Style</figcaption></center>
# </figure>

# %% [markdown]
# ### Calculate general Graph statistics

# %%
general_graph_stats_2 = general_graph_statistics(graph_2)
general_graph_stats_2
# Out:
#        clustering_coefficient  average_shortest_path  network_density  \
# score                0.369393               1.646154         0.892308
#
#        network_transitivity
# score              0.919378

# %% [markdown]
# ### Calculate centrality measures

# %%
centralities_2 = calculate_centralities(graph_2)
centralities_2
# Out:
#                       node  degree_centrality  betweenness_centrality  \
# 0                   aerial               35.0                0.035499
# 1                 ashtanga               32.0                0.065105
# 2                 baptiste               20.0                0.066385
# 3                    barre               20.0                0.066385
# 4   breathwork / pranayama               62.0                0.005204
# 5                   dharma               35.0                0.035499
# 6                     flow               74.0                0.000000
# 7                    hatha               54.0                0.000196
# 8        hot yoga / bikram               62.0                0.005400
# 9                  iyengar               62.0                0.005400
# 10               jivamukti               30.0                0.000000
# 11                   karma               54.0                0.000196
# ...

# %%
plot_centralities_distributions(centralities_2)

# %% [markdown]
# ### Investigate Groups of nodes

# %%
clusters_2 = calculate_clusters(graph_2)
clusters_2
# Out:
#     Cluster                                            Members
# 0         1  ({ashtanga, meditation, kundalini, hatha, hot ...
# 1         2  ({ashtanga, meditation, kundalini, hatha, hot ...
# 2         3  ({ashtanga, meditation, kundalini, hatha, hot ...
# 3         4  ({ashtanga, meditation, kundalini, hot yoga / ...
# 4         5  ({ashtanga, meditation, kundalini, hot yoga / ...
# 5         6  ({aerial}, {ashtanga, meditation, kundalini, h...
# 6         7  ({aerial}, {ashtanga}, {meditation, kundalini,...
# 7         8  ({aerial}, {ashtanga}, {baptiste}, {meditation...
# 8         9  ({aerial}, {ashtanga}, {baptiste}, {barre}, {m...
# 9        10  ({aerial}, {ashtanga}, {baptiste}, {barre}, {b...
# 10       11  ({aerial}, {ashtanga}, {baptiste}, {barre}, {b...
# 11       12  ({aerial}, {ashtanga}, {baptiste}, {barre}, {b...
# 12       13  ({aerial}, {ashtanga}, {baptiste}, {barre}, {b...
# 13       14  ({aerial}, {ashtanga}, {baptiste}, {barre}, {b...
# ...

# %%
communities_2 = detect_communities(graph_2)
communities_2
# Out:
#    Community                                            Members
# 0          1  (ashtanga, meditation, kundalini, hatha, karma...
# 1          2  (aerial, dharma, qigong, training, baptiste, t...

# %% [markdown]
# # Network 3. *Narrative topic - Class Style* Relation

# %% [markdown]
# ### Construct the Graph

# %%
graph_3 = build_network_3(df_topics, styles, topics)

# %% [markdown]
# ### Visualize the network

# %% [markdown]
# Visualisation parameters:
#
# - node size is proportional to degree centrality of the node
# - edge width and color are proportional to edge weights

# %%
# save the graph data to import to Gephi for visualisation

graph_to_csv(graph_3, '', 'graph_3')

# %% [markdown]
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=1EhYhLvejUESIjC2AHn7qK2x4yS-Q4yXm'/>
# <figcaption>Network 3: Narrative Topic - Class Style</figcaption></center>
# </figure>

# %% [markdown]
# ### Calculate general Graph statistics

# %%
clustering_coefficient_3 = calculate_clustering_coefficient_bipartite(graph_3)
print('Clustering coefficient: ', clustering_coefficient_3)
network_density_3 = calculate_density_bipartite(graph_3, topics)
print('Network density: ', network_density_3)


# to be added
# Out:
# Clustering coefficient:  1.0
# Network density:  1.0

# %% [markdown]
# ### Calculate centrality measures

# %%
centralities_3 = calculate_centralities_bipartite(graph_3, topics)
centralities_3
# Out:
#                                node  degree_centrality  \
# 0                          ashtanga           1.000000
# 1                        meditation           1.000000
# 2                         kundalini           1.000000
# 3                             hatha           1.000000
# 4                             barre           1.000000
# 5                             karma           1.000000
# 6                               yin           1.000000
# 7                 hot yoga / bikram           1.000000
# 8                           tai chi           1.000000
# 9                         jivamukti           1.000000
# 10                            nidra           1.000000
# 11                           dharma           1.000000
# 12                         training           1.000000
# 13           yoga for kids / family           1.000000
# 14                          vinyasa           1.000000
# 15                             flow           1.000000
# ...

# %% [markdown]
# ### One-mode projection

# %%
topics_projection_graph = node_projection(graph_3, 'topics')

# to be explored
